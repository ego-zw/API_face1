# %% [markdown]
# # 使用三种API开放平台实现人脸识别

# %% [markdown]
# * 使用的单人示例图片
# ![image](http://p2.ifengimg.com/a/2016_22/1c6aa2190dc6a9d_size473_w1024_h1302.jpg)
# * 使用的多人示例图片
# ![image](https://inews.gtimg.com/newsapp_bt/0/105244316/1000)
# ![image](http://shishi.dqdaily.com/attachement/jpeg/site2/20190517/0025114f3db41e48567904.jpeg)

# %% [markdown]
# ## Azure

# %% [markdown]
# - 单人人脸识别数据

# %%
import requests
import json

# set to your own subscription key value
subscription_key = '262e507a521140c498358a813d03b931'
assert subscription_key

# replace <My Endpoint String> with the string from your endpoint URL
face_api_url = 'https://simon-zw.cognitiveservices.azure.com/face/v1.0/detect'

image_url = 'http://p2.ifengimg.com/a/2016_22/1c6aa2190dc6a9d_size473_w1024_h1302.jpg'

headers = {'Ocp-Apim-Subscription-Key': subscription_key}

params = {
    'returnFaceId': 'true',
    'returnFaceLandmarks': 'false',
    'returnFaceAttributes': 'age,gender,headPose,smile,facialHair,glasses,emotion,hair,makeup,occlusion,accessories,blur,exposure,noise',
}

response = requests.post(face_api_url, params=params,
                         headers=headers, json={"url": image_url})
print(json.dumps(response.json()))
# Out:
# [{"faceId": "352242f5-6952-4505-8716-23659994cee4", "faceRectangle": {"top": 173, "left": 397, "width": 217, "height": 217}, "faceAttributes": {"smile": 0.012, "headPose": {"pitch": -6.7, "roll": 5.2, "yaw": 0.9}, "gender": "male", "age": 25.0, "facialHair": {"moustache": 0.1, "beard": 0.1, "sideburns": 0.1}, "glasses": "NoGlasses", "emotion": {"anger": 0.002, "contempt": 0.448, "disgust": 0.001, "fear": 0.001, "happiness": 0.012, "neutral": 0.528, "sadness": 0.004, "surprise": 0.005}, "blur": {"blurLevel": "low", "value": 0.0}, "exposure": {"exposureLevel": "goodExposure", "value": 0.57}, "noise": {"noiseLevel": "low", "value": 0.14}, "makeup": {"eyeMakeup": true, "lipMakeup": true}, "accessories": [], "occlusion": {"foreheadOccluded": false, "eyeOccluded": false, "mouthOccluded": false}, "hair": {"bald": 0.05, "invisible": false, "hairColor": [{"color": "brown", "confidence": 0.99}, {"color": "black", "confidence": 0.89}, {"color": "red", "confidence": 0.32}, {"color": "other", "confidence": 0.14}, {"color": "gray", "confidence": 0.11}, {"color": "blond", "confidence": 0.07}]}}}]

# %% [markdown]
# - 多人人脸识别数据

# %%
import requests
import json

# set to your own subscription key value
subscription_key = '262e507a521140c498358a813d03b931'
assert subscription_key

# replace <My Endpoint String> with the string from your endpoint URL
face_api_url = 'https://simon-zw.cognitiveservices.azure.com/face/v1.0/detect'

image_url = 'https://inews.gtimg.com/newsapp_bt/0/105244316/1000'

headers = {'Ocp-Apim-Subscription-Key': subscription_key}

params2 = {
    'returnFaceId': 'true',
    'returnFaceLandmarks': 'false',
    'returnFaceAttributes': 'age,gender,headPose,smile,facialHair,glasses,emotion,hair,makeup,occlusion,accessories,blur,exposure,noise',
}
response2 = requests.post(face_api_url, params=params2,
                         headers=headers, json={"url": image_url})
print(json.dumps(response2.json()))
# Out:
# [{"faceId": "7f790079-5580-4125-98df-8bb66a4f2ac3", "faceRectangle": {"top": 152, "left": 330, "width": 44, "height": 44}, "faceAttributes": {"smile": 0.371, "headPose": {"pitch": -1.3, "roll": -0.3, "yaw": 1.2}, "gender": "male", "age": 23.0, "facialHair": {"moustache": 0.1, "beard": 0.1, "sideburns": 0.1}, "glasses": "NoGlasses", "emotion": {"anger": 0.0, "contempt": 0.001, "disgust": 0.0, "fear": 0.0, "happiness": 0.371, "neutral": 0.628, "sadness": 0.0, "surprise": 0.0}, "blur": {"blurLevel": "low", "value": 0.06}, "exposure": {"exposureLevel": "goodExposure", "value": 0.68}, "noise": {"noiseLevel": "low", "value": 0.0}, "makeup": {"eyeMakeup": true, "lipMakeup": true}, "accessories": [], "occlusion": {"foreheadOccluded": false, "eyeOccluded": false, "mouthOccluded": false}, "hair": {"bald": 0.06, "invisible": false, "hairColor": [{"color": "brown", "confidence": 0.97}, {"color": "black", "confidence": 0.95}, {"color": "gray", "confidence": 0.31}, {"color": "blond", "confidence": 0.23}, {"color": "other", "confidence": 0.13}, {"color": "red", "confidence": 0.07}]}}}, {"faceId": "32367e29-44d9-489c-a32c-3e047d0bed5e", "faceRectangle": {"top": 184, "left": 202, "width": 43, "height": 43}, "faceAttributes": {"smile": 0.0, "headPose": {"pitch": -5.8, "roll": 1.1, "yaw": 25.0}, "gender": "female", "age": 22.0, "facialHair": {"moustache": 0.0, "beard": 0.0, "sideburns": 0.0}, "glasses": "NoGlasses", "emotion": {"anger": 0.0, "contempt": 0.0, "disgust": 0.0, "fear": 0.0, "happiness": 0.0, "neutral": 0.073, "sadness": 0.0, "surprise": 0.926}, "blur": {"blurLevel": "low", "value": 0.0}, "exposure": {"exposureLevel": "goodExposure", "value": 0.7}, "noise": {"noiseLevel": "high", "value": 0.87}, "makeup": {"eyeMakeup": true, "lipMakeup": true}, "accessories": [], "occlusion": {"foreheadOccluded": false, "eyeOccluded": false, "mouthOccluded": false}, "hair": {"bald": 0.04, "invisible": false, "hairColor": [{"color": "black", "confidence": 1.0}, {"color": "brown", "confidence": 0.87}, {"color": "other", "confidence": 0.39}, {"color": "gray", "confidence": 0.28}, {"color": "blond", "confidence": 0.04}, {"color": "red", "confidence": 0.03}]}}}]

# %%
import requests
import json

# set to your own subscription key value
subscription_key = '262e507a521140c498358a813d03b931'
assert subscription_key

# replace <My Endpoint String> with the string from your endpoint URL
face_api_url = 'https://simon-zw.cognitiveservices.azure.com/face/v1.0/detect'

image_url = 'http://shishi.dqdaily.com/attachement/jpeg/site2/20190517/0025114f3db41e48567904.jpeg'

headers = {'Ocp-Apim-Subscription-Key': subscription_key}

params2 = {
    'returnFaceId': 'true',
    'returnFaceLandmarks': 'false',
    'returnFaceAttributes': 'age,gender,headPose,smile,facialHair,glasses,emotion,hair,makeup,occlusion,accessories,blur,exposure,noise',
}
response2 = requests.post(face_api_url, params=params2,
                         headers=headers, json={"url": image_url})
print(json.dumps(response2.json()))
# Out:
# [{"faceId": "37d58420-1611-48c5-98d3-16fc0f4aba2b", "faceRectangle": {"top": 169, "left": 285, "width": 114, "height": 114}, "faceAttributes": {"smile": 1.0, "headPose": {"pitch": 6.8, "roll": -16.8, "yaw": -12.7}, "gender": "male", "age": 26.0, "facialHair": {"moustache": 0.1, "beard": 0.1, "sideburns": 0.1}, "glasses": "NoGlasses", "emotion": {"anger": 0.0, "contempt": 0.0, "disgust": 0.0, "fear": 0.0, "happiness": 1.0, "neutral": 0.0, "sadness": 0.0, "surprise": 0.0}, "blur": {"blurLevel": "medium", "value": 0.68}, "exposure": {"exposureLevel": "goodExposure", "value": 0.58}, "noise": {"noiseLevel": "high", "value": 0.71}, "makeup": {"eyeMakeup": false, "lipMakeup": false}, "accessories": [], "occlusion": {"foreheadOccluded": false, "eyeOccluded": false, "mouthOccluded": false}, "hair": {"bald": 0.17, "invisible": false, "hairColor": [{"color": "brown", "confidence": 0.98}, {"color": "black", "confidence": 0.95}, {"color": "red", "confidence": 0.22}, {"color": "other", "confidence": 0.21}, {"color": "gray", "confidence": 0.2}, {"color": "blond", "confidence": 0.05}]}}}, {"faceId": "c6fcd741-78b5-424c-a42e-6140ddd408ed", "faceRectangle": {"top": 95, "left": 450, "width": 74, "height": 74}, "faceAttributes": {"smile": 1.0, "headPose": {"pitch": -5.4, "roll": -17.6, "yaw": -19.2}, "gender": "male", "age": 31.0, "facialHair": {"moustache": 0.1, "beard": 0.1, "sideburns": 0.1}, "glasses": "NoGlasses", "emotion": {"anger": 0.0, "contempt": 0.0, "disgust": 0.0, "fear": 0.0, "happiness": 1.0, "neutral": 0.0, "sadness": 0.0, "surprise": 0.0}, "blur": {"blurLevel": "high", "value": 1.0}, "exposure": {"exposureLevel": "goodExposure", "value": 0.65}, "noise": {"noiseLevel": "medium", "value": 0.39}, "makeup": {"eyeMakeup": false, "lipMakeup": false}, "accessories": [], "occlusion": {"foreheadOccluded": false, "eyeOccluded": false, "mouthOccluded": false}, "hair": {"bald": 0.19, "invisible": false, "hairColor": [{"color": "black", "confidence": 0.97}, {"color": "brown", "confidence": 0.88}, {"color": "gray", "confidence": 0.54}, {"color": "blond", "confidence": 0.39}, {"color": "other", "confidence": 0.18}, {"color": "red", "confidence": 0.02}]}}}, {"faceId": "1958e854-0811-4a50-a093-c41f762e7110", "faceRectangle": {"top": 111, "left": 191, "width": 56, "height": 56}, "faceAttributes": {"smile": 0.904, "headPose": {"pitch": 3.5, "roll": 4.2, "yaw": 5.4}, "gender": "male", "age": 24.0, "facialHair": {"moustache": 0.1, "beard": 0.1, "sideburns": 0.1}, "glasses": "NoGlasses", "emotion": {"anger": 0.0, "contempt": 0.001, "disgust": 0.0, "fear": 0.0, "happiness": 0.904, "neutral": 0.095, "sadness": 0.0, "surprise": 0.0}, "blur": {"blurLevel": "high", "value": 0.96}, "exposure": {"exposureLevel": "goodExposure", "value": 0.57}, "noise": {"noiseLevel": "low", "value": 0.18}, "makeup": {"eyeMakeup": true, "lipMakeup": true}, "accessories": [], "occlusion": {"foreheadOccluded": false, "eyeOccluded": false, "mouthOccluded": false}, "hair": {"bald": 0.02, "invisible": false, "hairColor": [{"color": "brown", "confidence": 1.0}, {"color": "black", "confidence": 0.91}, {"color": "red", "confidence": 0.19}, {"color": "blond", "confidence": 0.14}, {"color": "gray", "confidence": 0.12}, {"color": "other", "confidence": 0.06}]}}}, {"faceId": "f676b46b-386d-419d-9899-6be914010081", "faceRectangle": {"top": 104, "left": 47, "width": 56, "height": 56}, "faceAttributes": {"smile": 1.0, "headPose": {"pitch": 0.1, "roll": 4.4, "yaw": 15.4}, "gender": "male", "age": 31.0, "facialHair": {"moustache": 0.1, "beard": 0.1, "sideburns": 0.1}, "glasses": "NoGlasses", "emotion": {"anger": 0.0, "contempt": 0.0, "disgust": 0.0, "fear": 0.0, "happiness": 1.0, "neutral": 0.0, "sadness": 0.0, "surprise": 0.0}, "blur": {"blurLevel": "medium", "value": 0.71}, "exposure": {"exposureLevel": "goodExposure", "value": 0.7}, "noise": {"noiseLevel": "medium", "value": 0.3}, "makeup": {"eyeMakeup": false, "lipMakeup": false}, "accessories": [], "occlusion": {"foreheadOccluded": false ...

# %% [markdown]
# ## 腾讯云

# %% [markdown]
# - 单人人脸识别数据

# %%
import hashlib  
import time  
import random  
import string
import requests  
import base64  
import requests

import numpy as np
from urllib.parse import urlencode
import json #用于post后得到的字符串到字典的转换

app_id = '2131690713' 
app_key = 'YDtKcITUF0dF49d3'


def face_check(img_data):
    """
    人脸识别demo
    :param img_data: 二进制的图片数据
    :return:
    """

    data = base64.b64encode(img_data)

    image = data.decode()

    imageType = "BASE64"
    
def get_params(img):                         #鉴权计算并返回请求参数
    #请求时间戳（秒级），用于防止请求重放（保证签名5分钟有效
    time_stamp=str(int(time.time())) 
    #请求随机字符串，用于保证签名不可预测,16代表16位
    nonce_str = ''.join(random.sample(string.ascii_letters + string.digits, 16))

    params3 = {'app_id':app_id,                #请求包，需要根据不同的任务修改，基本相同
              'image':img,                    #文字类的任务可能是‘text’，由主函数传递进来
              'mode':'0' ,                    #身份证件类可能是'card_type'
              'time_stamp':time_stamp,        #时间戳，都一样
              'nonce_str':nonce_str,          #随机字符串，都一样
              #'sign':''                      #签名不参与鉴权计算，只是列出来示意
             }

    sort_dict= sorted(params3.items(), key=lambda item:item[0], reverse = False)  #字典排序
    sort_dict.append(('app_key',app_key))   #尾部添加appkey
    rawtext= urlencode(sort_dict).encode()  #urlencod编码
    sha = hashlib.md5()    
    sha.update(rawtext)
    md5text= sha.hexdigest().upper()        #MD5加密计算
    params3['sign']=md5text                  #将签名赋值到sign
    return  params3                          #返回请求包

with open(r"C:\Users\14470\Desktop\666.jpg","rb")as f:
    base64_data = base64.b64encode(f.read())
    
params3 = get_params(base64_data)

url = "https://api.ai.qq.com/fcgi-bin/face/face_detectface"
res = requests.post(url,params3).json()
print(res)
# Out:
# {'ret': 0, 'msg': 'ok', 'data': {'image_width': 1024, 'image_height': 1302, 'face_list': [{'face_id': '3591677007410278502', 'x': 391, 'y': 159, 'width': 241, 'height': 241, 'gender': 99, 'age': 22, 'expression': 11, 'beauty': 84, 'glass': 0, 'pitch': 8, 'yaw': 2, 'roll': -5, 'face_shape': {'face_profile': [{'x': 407, 'y': 224}, {'x': 405, 'y': 246}, {'x': 406, 'y': 269}, {'x': 409, 'y': 291}, {'x': 413, 'y': 313}, {'x': 420, 'y': 334}, {'x': 431, 'y': 353}, {'x': 445, 'y': 371}, {'x': 461, 'y': 386}, {'x': 479, 'y': 398}, {'x': 501, 'y': 404}, {'x': 522, 'y': 401}, {'x': 540, 'y': 390}, {'x': 557, 'y': 376}, {'x': 571, 'y': 360}, {'x': 583, 'y': 343}, {'x': 592, 'y': 323}, {'x': 599, 'y': 303}, {'x': 605, 'y': 283}, {'x': 608, 'y': 261}, {'x': 609, 'y': 242}], 'left_eye': [{'x': 443, 'y': 227}, {'x': 450, 'y': 235}, {'x': 461, 'y': 239}, {'x': 472, 'y': 239}, {'x': 483, 'y': 235}, {'x': 477, 'y': 225}, {'x': 466, 'y': 220}, {'x': 453, 'y': 220}], 'right_eye': [{'x': 574, 'y': 239}, {'x': 565, 'y': 244}, {'x': 554, 'y': 246}, {'x': 544, 'y': 243}, {'x': 534, 'y': 237}, {'x': 543, 'y': 230}, {'x': 554, 'y': 228}, {'x': 565, 'y': 231}], 'left_eyebrow': [{'x': 426, 'y': 207}, {'x': 441, 'y': 206}, {'x': 457, 'y': 206}, {'x': 473, 'y': 208}, {'x': 488, 'y': 208}, {'x': 474, 'y': 197}, {'x': 457, 'y': 194}, {'x': 439, 'y': 195}], 'right_eyebrow': [{'x': 596, 'y': 221}, {'x': 578, 'y': 220}, {'x': 560, 'y': 219}, {'x': 542, 'y': 219}, {'x': 524, 'y': 218}, {'x': 541, 'y': 208}, {'x': 561, 'y': 206}, {'x': 581, 'y': 208}], 'mouth': [{'x': 464, 'y': 331}, {'x': 476, 'y': 338}, {'x': 489, 'y': 343}, {'x': 503, 'y': 344}, {'x': 516, 'y': 344}, {'x': 529, 'y': 340}, {'x': 541, 'y': 334}, {'x': 527, 'y': 334}, {'x': 512, 'y': 333}, {'x': 503, 'y': 335}, {'x': 495, 'y': 333}, {'x': 479, 'y': 332}, {'x': 477, 'y': 334}, {'x': 490, 'y': 337}, {'x': 503, 'y': 339}, {'x': 516, 'y': 338}, {'x': 529, 'y': 336}, {'x': 529, 'y': 336}, {'x': 516, 'y': 337}, {'x': 503, 'y': 339}, {'x': 490, 'y': 336}, {'x': 477, 'y': 334}], 'nose': [{'x': 506, 'y': 288}, {'x': 509, 'y': 235}, {'x': 500, 'y': 250}, {'x': 492, 'y': 264}, {'x': 484, 'y': 278}, {'x': 475, 'y': 294}, {'x': 490, 'y': 303}, {'x': 504, 'y': 307}, {'x': 517, 'y': 306}, {'x': 532, 'y': 299}, {'x': 526, 'y': 282}, {'x': 520, 'y': 266}, {'x': 514, 'y': 251}]}}]}}

# %% [markdown]
# - 多人人脸识别数据

# %%
import hashlib  
import time  
import random  
import string
import requests  
import base64  
import requests

import numpy as np
from urllib.parse import urlencode
import json #用于post后得到的字符串到字典的转换

app_id = '2131690713' 
app_key = 'YDtKcITUF0dF49d3'



def face_check(img_data):
    """
    人脸识别demo
    :param img_data: 二进制的图片数据
    :return:
    """

    data = base64.b64encode(img_data)

    image = data.decode()

    imageType = "BASE64"
    
def get_params(img):                         #鉴权计算并返回请求参数
    #请求时间戳（秒级），用于防止请求重放（保证签名5分钟有效
    time_stamp=str(int(time.time())) 
    #请求随机字符串，用于保证签名不可预测,16代表16位
    nonce_str = ''.join(random.sample(string.ascii_letters + string.digits, 16))

    params4 = {'app_id':app_id,                #请求包，需要根据不同的任务修改，基本相同
              'image':img,                    #文字类的任务可能是‘text’，由主函数传递进来
              'mode':'0' ,                    #身份证件类可能是'card_type'
              'time_stamp':time_stamp,        #时间戳，都一样
              'nonce_str':nonce_str,          #随机字符串，都一样
              #'sign':''                      #签名不参与鉴权计算，只是列出来示意
             }

    sort_dict= sorted(params4.items(), key=lambda item:item[0], reverse = False)  #字典排序
    sort_dict.append(('app_key',app_key))   #尾部添加appkey
    rawtext= urlencode(sort_dict).encode()  #urlencod编码
    sha = hashlib.md5()    
    sha.update(rawtext)
    md5text= sha.hexdigest().upper()        #MD5加密计算
    params4['sign']=md5text                  #将签名赋值到sign
    return  params4                         #返回请求包

with open(r"C:\Users\14470\Desktop\777.jpg","rb")as f:
    base64_data = base64.b64encode(f.read())
    
params4 = get_params(base64_data)

url = "https://api.ai.qq.com/fcgi-bin/face/face_detectface"
res2 = requests.post(url,params4).json()
print(res2)
# Out:
# {'ret': 0, 'msg': 'ok', 'data': {'image_width': 640, 'image_height': 431, 'face_list': [{'face_id': '3591710753910987410', 'x': 325, 'y': 150, 'width': 51, 'height': 51, 'gender': 99, 'age': 23, 'expression': 14, 'beauty': 78, 'glass': 0, 'pitch': 7, 'yaw': 3, 'roll': 0, 'face_shape': {'face_profile': [{'x': 329, 'y': 164}, {'x': 329, 'y': 168}, {'x': 330, 'y': 173}, {'x': 331, 'y': 178}, {'x': 332, 'y': 182}, {'x': 334, 'y': 186}, {'x': 336, 'y': 190}, {'x': 339, 'y': 194}, {'x': 343, 'y': 197}, {'x': 347, 'y': 199}, {'x': 352, 'y': 200}, {'x': 356, 'y': 199}, {'x': 360, 'y': 196}, {'x': 363, 'y': 193}, {'x': 366, 'y': 190}, {'x': 368, 'y': 186}, {'x': 370, 'y': 181}, {'x': 371, 'y': 177}, {'x': 372, 'y': 172}, {'x': 372, 'y': 168}, {'x': 372, 'y': 164}], 'left_eye': [{'x': 338, 'y': 164}, {'x': 339, 'y': 165}, {'x': 341, 'y': 165}, {'x': 344, 'y': 165}, {'x': 346, 'y': 165}, {'x': 344, 'y': 163}, {'x': 342, 'y': 162}, {'x': 340, 'y': 162}], 'right_eye': [{'x': 365, 'y': 164}, {'x': 363, 'y': 165}, {'x': 361, 'y': 165}, {'x': 359, 'y': 165}, {'x': 357, 'y': 165}, {'x': 359, 'y': 163}, {'x': 361, 'y': 162}, {'x': 363, 'y': 162}], 'left_eyebrow': [{'x': 334, 'y': 159}, {'x': 337, 'y': 159}, {'x': 341, 'y': 158}, {'x': 344, 'y': 158}, {'x': 347, 'y': 158}, {'x': 344, 'y': 156}, {'x': 341, 'y': 156}, {'x': 337, 'y': 157}], 'right_eyebrow': [{'x': 369, 'y': 159}, {'x': 366, 'y': 159}, {'x': 362, 'y': 159}, {'x': 359, 'y': 159}, {'x': 356, 'y': 159}, {'x': 359, 'y': 157}, {'x': 363, 'y': 156}, {'x': 366, 'y': 157}], 'mouth': [{'x': 343, 'y': 184}, {'x': 345, 'y': 186}, {'x': 348, 'y': 187}, {'x': 352, 'y': 187}, {'x': 355, 'y': 187}, {'x': 358, 'y': 186}, {'x': 360, 'y': 184}, {'x': 357, 'y': 184}, {'x': 354, 'y': 183}, {'x': 352, 'y': 183}, {'x': 349, 'y': 183}, {'x': 346, 'y': 184}, {'x': 346, 'y': 185}, {'x': 349, 'y': 185}, {'x': 352, 'y': 185}, {'x': 355, 'y': 185}, {'x': 357, 'y': 185}, {'x': 357, 'y': 184}, {'x': 355, 'y': 185}, {'x': 352, 'y': 185}, {'x': 349, 'y': 185}, {'x': 346, 'y': 185}], 'nose': [{'x': 352, 'y': 175}, {'x': 351, 'y': 164}, {'x': 350, 'y': 167}, {'x': 348, 'y': 170}, {'x': 347, 'y': 173}, {'x': 345, 'y': 177}, {'x': 349, 'y': 178}, {'x': 352, 'y': 179}, {'x': 355, 'y': 178}, {'x': 358, 'y': 176}, {'x': 356, 'y': 173}, {'x': 355, 'y': 170}, {'x': 353, 'y': 167}]}}, {'face_id': '3591710758945200786', 'x': 194, 'y': 179, 'width': 51, 'height': 51, 'gender': 0, 'age': 20, 'expression': 20, 'beauty': 85, 'glass': 0, 'pitch': 9, 'yaw': 18, 'roll': 1, 'face_shape': {'face_profile': [{'x': 199, 'y': 195}, {'x': 199, 'y': 199}, {'x': 200, 'y': 204}, {'x': 201, 'y': 208}, {'x': 203, 'y': 212}, {'x': 206, 'y': 215}, {'x': 209, 'y': 217}, {'x': 213, 'y': 219}, {'x': 217, 'y': 221}, {'x': 221, 'y': 221}, {'x': 226, 'y': 220}, {'x': 228, 'y': 219}, {'x': 230, 'y': 216}, {'x': 232, 'y': 214}, {'x': 233, 'y': 211}, {'x': 235, 'y': 209}, {'x': 236, 'y': 206}, {'x': 237, 'y': 203}, {'x': 238, 'y': 200}, {'x': 238, 'y': 196}, {'x': 238, 'y': 194}], 'left_eye': [{'x': 211, 'y': 194}, {'x': 212, 'y': 195}, {'x': 214, 'y': 196}, {'x': 216, 'y': 196}, {'x': 218, 'y': 195}, {'x': 217, 'y': 193}, {'x': 215, 'y': 192}, {'x': 213, 'y': 192}], 'right_eye': [{'x': 229, 'y': 195}, {'x': 231, 'y': 196}, {'x': 232, 'y': 196}, {'x': 233, 'y': 195}, {'x': 235, 'y': 194}, {'x': 233, 'y': 193}, {'x': 231, 'y': 192}, {'x': 230, 'y': 193}], 'left_eyebrow': [{'x': 207, 'y': 189}, {'x': 211, 'y': 189}, {'x': 214, 'y': 189}, {'x': 218, 'y': 190}, {'x': 222, 'y': 190}, {'x': 219, 'y': 188}, {'x': 215, 'y': 187}, {'x': 210, 'y': 187}], 'right_eyebrow': [{'x': 237, 'y': 190}, {'x': 234, 'y': 190}, {'x': 232, 'y': 190}, {'x': 230, 'y': 190}, {'x': 228, 'y': 190}, {'x': 230, 'y': 189}, {'x': 232, 'y': 188}, {'x': 235, 'y': 188}], 'mouth': [{'x': 218, 'y': 220}, {'x': 221, 'y': 220}, {'x': 223, 'y': 221}, {'x': 226, 'y': 220}, {'x': 227, 'y': 218}, {'x': 228, 'y': 217}, {'x': 228, 'y': 215}, {'x': 228, 'y': 214}, {'x': 227, 'y': 214}, {'x': 226, 'y ...

# %% [markdown]
# ## Face++

# %% [markdown]
# - 单人人脸识别数据

# %%
import requests


api_secret = "LvTZ17zvA4W5bBYyWYwRV7E53SX3FVbi"
api_key = 'bWvdxX9rhU715F4YYx34blCIS5ZGBmsk'  # Replace with a valid Subscription Key here.

BASE_URL = 'https://api-cn.faceplusplus.com/facepp/v3/detect' 
img_url = 'http://p2.ifengimg.com/a/2016_22/1c6aa2190dc6a9d_size473_w1024_h1302.jpg'

headers = {
    'Content-Type': 'application/json',
}

payload = {
    "image_url":img_url,
    'api_key': api_key,
    'api_secret': api_secret,
    'return_attributes':'gender,age,smiling,emotion', 
}

r = requests.post(BASE_URL, params=payload, headers=headers)

r.status_code
print(r.content)
# Out:
# b'{"request_id":"1586688761,2787e3ec-6967-41ca-af3b-7cf2345763e6","time_used":1378,"faces":[{"face_token":"7b80b263bb5bc1c47c42637d60748ff3","face_rectangle":{"top":199,"left":403,"width":204,"height":204},"attributes":{"gender":{"value":"Male"},"age":{"value":22},"smile":{"value":0.313,"threshold":50.000},"emotion":{"anger":0.000,"disgust":0.000,"fear":0.000,"happiness":0.064,"neutral":99.932,"sadness":0.000,"surprise":0.004}}}],"image_id":"dRwDYxEHDz3BXhnlNlkSeQ==","face_num":1}\n'

# %% [markdown]
# - 多人人脸识别数据

# %%
import requests


api_secret = "LvTZ17zvA4W5bBYyWYwRV7E53SX3FVbi"
api_key = 'bWvdxX9rhU715F4YYx34blCIS5ZGBmsk'  # Replace with a valid Subscription Key here.

BASE_URL = 'https://api-cn.faceplusplus.com/facepp/v3/detect' 
img_url = 'https://inews.gtimg.com/newsapp_bt/0/105244316/1000'

headers = {
    'Content-Type': 'application/json',
}

payload2 = {
    "image_url":img_url,
    'api_key': api_key,
    'api_secret': api_secret,
    'return_attributes':'gender,age,smiling,emotion', 
}

r2 = requests.post(BASE_URL, params=payload2, headers=headers)

r2.status_code
print(r2.content)
# Out:
# b'{"request_id":"1586688766,46fc76f5-2368-4328-a394-1a20f39bb8bd","time_used":1951,"faces":[{"face_token":"ea48938a0dd1fe0b4e43fcfb40c7f6c4","face_rectangle":{"top":156,"left":330,"width":43,"height":43},"attributes":{"gender":{"value":"Male"},"age":{"value":25},"smile":{"value":49.782,"threshold":50.000},"emotion":{"anger":0.003,"disgust":0.003,"fear":0.003,"happiness":79.190,"neutral":20.712,"sadness":0.073,"surprise":0.016}}},{"face_token":"c414621822c5038f1e9791b97b9420c1","face_rectangle":{"top":187,"left":198,"width":40,"height":40},"attributes":{"gender":{"value":"Female"},"age":{"value":22},"smile":{"value":1.678,"threshold":50.000},"emotion":{"anger":0.014,"disgust":0.014,"fear":45.168,"happiness":0.032,"neutral":0.025,"sadness":0.150,"surprise":54.599}}}],"image_id":"9ppMqFVZyZUwrHCtBIVVzA==","face_num":2}\n'

# %%
import requests


api_secret = "LvTZ17zvA4W5bBYyWYwRV7E53SX3FVbi"
api_key = 'bWvdxX9rhU715F4YYx34blCIS5ZGBmsk'  # Replace with a valid Subscription Key here.

BASE_URL = 'https://api-cn.faceplusplus.com/facepp/v3/detect' 
img_url = 'http://shishi.dqdaily.com/attachement/jpeg/site2/20190517/0025114f3db41e48567904.jpeg'

headers = {
    'Content-Type': 'application/json',
}

payload2 = {
    "image_url":img_url,
    'api_key': api_key,
    'api_secret': api_secret,
    'return_attributes':'gender,age,smiling,emotion', 
}

r2 = requests.post(BASE_URL, params=payload2, headers=headers)

r2.status_code
print(r2.content)
# Out:
# b'{"request_id":"1586690525,97e02306-916e-4c21-a225-0681b35ccfeb","time_used":626,"faces":[{"face_token":"982205dcd1b1f8b565531e8810f671c3","face_rectangle":{"top":174,"left":298,"width":117,"height":117},"attributes":{"gender":{"value":"Male"},"age":{"value":33},"smile":{"value":99.994,"threshold":50.000},"emotion":{"anger":0.000,"disgust":0.000,"fear":0.000,"happiness":99.795,"neutral":0.044,"sadness":0.149,"surprise":0.012}}},{"face_token":"031ca75144ef6d0b552825d99d9e1199","face_rectangle":{"top":95,"left":458,"width":79,"height":79},"attributes":{"gender":{"value":"Male"},"age":{"value":42},"smile":{"value":100.000,"threshold":50.000},"emotion":{"anger":0.000,"disgust":0.000,"fear":0.001,"happiness":99.990,"neutral":0.000,"sadness":0.008,"surprise":0.000}}},{"face_token":"0ac6d248ada5c4711dc2560d5a9367d4","face_rectangle":{"top":109,"left":37,"width":56,"height":56},"attributes":{"gender":{"value":"Male"},"age":{"value":30},"smile":{"value":99.971,"threshold":50.000},"emotion":{"anger":0.000,"disgust":0.002,"fear":0.000,"happiness":99.694,"neutral":0.301,"sadness":0.000,"surprise":0.003}}},{"face_token":"9a00fdf4b2aa0a6ee182cb8c2e1e90ec","face_rectangle":{"top":115,"left":189,"width":56,"height":56},"attributes":{"gender":{"value":"Male"},"age":{"value":24},"smile":{"value":99.834,"threshold":50.000},"emotion":{"anger":0.004,"disgust":0.004,"fear":0.034,"happiness":86.613,"neutral":13.339,"sadness":0.004,"surprise":0.004}}},{"face_token":"d1ad067e4cf711bcb782abcfcb37d777","face_rectangle":{"top":59,"left":281,"width":54,"height":54},"attributes":{"gender":{"value":"Male"},"age":{"value":31},"smile":{"value":0.019,"threshold":50.000},"emotion":{"anger":0.001,"disgust":0.000,"fear":0.001,"happiness":0.000,"neutral":99.963,"sadness":0.001,"surprise":0.034}}},{"face_token":"b62e6330351a33a7af6eb71de08bfc53","face_rectangle":{"top":70,"left":390,"width":49,"height":49}},{"face_token":"2f06c88ac461caf73ddc87296c2a7229","face_rectangle":{"top":108,"left":124,"width":46,"height":46}}],"image_id":"T1cd/DyC1NDcHwPnSxBEzQ==","face_num":7}\n'

# %% [markdown]
# # 运用Azure分析人脸数据制作数据表格

# %% [markdown]
# - 单人人脸识别分析

# %%
results = response.json()
results
# Out:
# [{'faceId': '352242f5-6952-4505-8716-23659994cee4',
#   'faceRectangle': {'top': 173, 'left': 397, 'width': 217, 'height': 217},
#   'faceAttributes': {'smile': 0.012,
#    'headPose': {'pitch': -6.7, 'roll': 5.2, 'yaw': 0.9},
#    'gender': 'male',
#    'age': 25.0,
#    'facialHair': {'moustache': 0.1, 'beard': 0.1, 'sideburns': 0.1},
#    'glasses': 'NoGlasses',
#    'emotion': {'anger': 0.002,
#     'contempt': 0.448,
#     'disgust': 0.001,
#     'fear': 0.001,
#     'happiness': 0.012,
#     'neutral': 0.528,
#     'sadness': 0.004,
#     'surprise': 0.005},
#    'blur': {'blurLevel': 'low', 'value': 0.0},
#    'exposure': {'exposureLevel': 'goodExposure', 'value': 0.57},
#    'noise': {'noiseLevel': 'low', 'value': 0.14},
#    'makeup': {'eyeMakeup': True, 'lipMakeup': True},
#    'accessories': [],
#    'occlusion': {'foreheadOccluded': False,
#     'eyeOccluded': False,
#     'mouthOccluded': False},
#    'hair': {'bald': 0.05,
#     'invisible': False,
#     'hairColor': [{'color': 'brown', 'confidence': 0.99},
#      {'color': 'black', 'confidence': 0.89},
#      {'color': 'red', 'confidence': 0.32},
#      {'color': 'other', 'confidence': 0.14},
#      {'color': 'gray', 'confidence': 0.11},
#      {'color': 'blond', 'confidence': 0.07}]}}}]

# %%
import pandas as pd
df = pd.json_normalize(results)
df = df.rename (columns = {"faceAttributes.smile":"笑容","faceAttributes.headPose.roll":"头部偏向（上下）",
                           "faceAttributes.facialHair.beard":"胡须",
                           "faceAttributes.facialHair.sideburns":"胡须角",
                           "faceAttributes.glasses":"佩戴眼镜",
                           "faceAttributes.emotion.anger":"愤怒",
                           "faceAttributes.emotion.contempt":"鄙视",
                           "faceAttributes.headPose.yaw":"头部偏向（左右）",
                           "faceAttributes.gender":"性别","faceAttributes.age":"年龄",
                           "faceAttributes.facialHair.moustache":"有无胡子",
                           "faceAttributes.noise.value":"噪音值",
                           "faceAttributes.makeup.eyeMakeup":"眼妆",
                           "faceAttributes.makeup.lipMakeup":"唇彩",
                           "faceAttributes.accessories":"配饰",
                           "faceAttributes.occlusion.foreheadOccluded":"前额闭塞",
                           "faceAttributes.occlusion.eyeOccluded":"眼睛开合",
                           "faceAttributes.occlusion.mouthOccluded":"嘴巴开合",
                           "faceAttributes.hair.bald":"秃头程度",
                           "faceAttributes.hair.invisible":"看不见头发",
                           "faceAttributes.hair.hairColor":"发色"})
df = df.set_index('faceId')
df = df.iloc[:,6:]
df.replace({"male":"男",
            "female":"女",
            "NoGlasses":"不佩戴眼镜",
            "Glasses":"佩戴眼镜",})
# Out:
#                                       头部偏向（上下）  头部偏向（左右） 性别    年龄  有无胡子   胡须  \
# faceId
# 352242f5-6952-4505-8716-23659994cee4       5.2       0.9  男  25.0   0.1  0.1
#
#                                       胡须角   佩戴眼镜     愤怒     鄙视  ...   噪音值  \
# faceId                                                          ...
# 352242f5-6952-4505-8716-23659994cee4  0.1  不佩戴眼镜  0.002  0.448  ...  0.14
#
#                                         眼妆    唇彩  配饰   前额闭塞   眼睛开合   嘴巴开合  \
# faceId
# 352242f5-6952-4505-8716-23659994cee4  True  True  []  False  False  False
#
#                                       秃头程度  看不见头发  \
# faceId
# 352242f5-6952-4505-8716-23659994cee4  0.05  False
#
#                                                                                      发色
# faceId
# 352242f5-6952-4505-8716-23659994cee4  [{'color': 'brown', 'confidence': 0.99}, {'col...
#
# [1 rows x 31 columns]

# %% [markdown]
# - 多人人脸识别分析

# %%
results2 = response2.json()
results2
# Out:
# [{'faceId': '37d58420-1611-48c5-98d3-16fc0f4aba2b',
#   'faceRectangle': {'top': 169, 'left': 285, 'width': 114, 'height': 114},
#   'faceAttributes': {'smile': 1.0,
#    'headPose': {'pitch': 6.8, 'roll': -16.8, 'yaw': -12.7},
#    'gender': 'male',
#    'age': 26.0,
#    'facialHair': {'moustache': 0.1, 'beard': 0.1, 'sideburns': 0.1},
#    'glasses': 'NoGlasses',
#    'emotion': {'anger': 0.0,
#     'contempt': 0.0,
#     'disgust': 0.0,
#     'fear': 0.0,
#     'happiness': 1.0,
#     'neutral': 0.0,
#     'sadness': 0.0,
#     'surprise': 0.0},
#    'blur': {'blurLevel': 'medium', 'value': 0.68},
#    'exposure': {'exposureLevel': 'goodExposure', 'value': 0.58},
#    'noise': {'noiseLevel': 'high', 'value': 0.71},
#    'makeup': {'eyeMakeup': False, 'lipMakeup': False},
#    'accessories': [],
#    'occlusion': {'foreheadOccluded': False,
#     'eyeOccluded': False,
#     'mouthOccluded': False},
#    'hair': {'bald': 0.17,
#     'invisible': False,
#     'hairColor': [{'color': 'brown', 'confidence': 0.98},
#      {'color': 'black', 'confidence': 0.95},
#      {'color': 'red', 'confidence': 0.22},
#      {'color': 'other', 'confidence': 0.21},
#      {'color': 'gray', 'confidence': 0.2},
#      {'color': 'blond', 'confidence': 0.05}]}}},
#  {'faceId': 'c6fcd741-78b5-424c-a42e-6140ddd408ed',
#   'faceRectangle': {'top': 95, 'left': 450, 'width': 74, 'height': 74},
#   'faceAttributes': {'smile': 1.0,
#    'headPose': {'pitch': -5.4, 'roll': -17.6, 'yaw': -19.2},
#    'gender': 'male',
#    'age': 31.0,
#    'facialHair': {'moustache': 0.1, 'beard': 0.1, 'sideburns': 0.1},
#    'glasses': 'NoGlasses',
#    'emotion': {'anger': 0.0,
#     'contempt': 0.0,
#     'disgust': 0.0,
#     'fear': 0.0,
#     'happiness': 1.0,
#     'neutral': 0.0,
#     'sadness': 0.0,
#     'surprise': 0.0},
#    'blur': {'blurLevel': 'high', 'value': 1.0},
#    'exposure': {'exposureLevel': 'goodExposure', 'value': 0.65},
#    'noise': {'noiseLevel': 'medium', 'value': 0.39},
#    'makeup': {'eyeMakeup': False, 'lipMakeup': False},
#    'accessories': [],
#    'occlusion': {'foreheadOccluded': False,
#     'eyeOccluded': False,
#     'mouthOccluded': False},
#    'hair': {'bald': 0.19,
#     'invisible': False,
#     'hairColor': [{'color': 'black', 'confidence': 0.97},
#      {'color': 'brown', 'confidence': 0.88},
#      {'color': 'gray', 'confidence': 0.54},
#      {'color': 'blond', 'confidence': 0.39},
#      {'color': 'other', 'confidence': 0.18},
#      {'color': 'red', 'confidence': 0.02}]}}},
#  {'faceId': '1958e854-0811-4a50-a093-c41f762e7110',
#   'faceRectangle': {'top': 111, 'left': 191, 'width': 56, 'height': 56},
#   'faceAttributes': {'smile': 0.904,
#    'headPose': {'pitch': 3.5, 'roll': 4.2, 'yaw': 5.4},
#    'gender': 'male',
#    'age': 24.0,
#    'facialHair': {'moustache': 0.1, 'beard': 0.1, 'sideburns': 0.1},
#    'glasses': 'NoGlasses',
#    'emotion': {'anger': 0.0,
#     'contempt': 0.001,
#     'disgust': 0.0,
#     'fear': 0.0,
#     'happiness': 0.904,
#     'neutral': 0.095,
#     'sadness': 0.0,
#     'surprise': 0.0},
#    'blur': {'blurLevel': 'high', 'value': 0.96},
#    'exposure': {'exposureLevel': 'goodExposure', 'value': 0.57},
#    'noise': {'noiseLevel': 'low', 'value': 0.18},
#    'makeup': {'eyeMakeup': True, 'lipMakeup': True},
#    'accessories': [],
#    'occlusion': {'foreheadOccluded': False,
#     'eyeOccluded': False,
#     'mouthOccluded': False},
#    'hair': {'bald': 0.02,
#     'invisible': False,
#     'hairColor': [{'color': 'brown', 'confidence': 1.0},
#      {'color': 'black', 'confidence': 0.91},
#      {'color': 'red', 'confidence': 0.19},
#      {'color': 'blond', 'confidence': 0.14},
#      {'color': 'gray', 'confidence': 0.12},
#      {'color': 'other', 'confidence': 0.06}]}}},
#  {'faceId': 'f676b46b-386d-419d-9899-6be914010081',
#   'faceRectangle': {'top': 104, 'left': 47, 'width': 56, 'height': 56},
#   'faceAttributes': {'smile': 1.0,
#    'headPose': {'pitch': 0.1, 'roll': 4.4, 'yaw': 15.4},
#    'gender': 'male',
#    'age': 31.0,
#    'facialHair': {'moustache': 0.1, 'beard': 0.1, 'sideburns': 0.1},
#    'glasses': 'NoGlasses',
#    'emotion': {'anger': 0.0,
#     'contempt': 0.0,
#     'disgust': 0.0,
#     'fear': 0.0,
#     'happiness': 1.0,
#     'neutral': 0.0,
#     'sadness': 0.0,
#     'surprise': 0.0},
#    'blur': {'blurLevel': 'medium', 'value': 0.71},
#    'exposure': {'exposureLevel': 'goodExposure', 'value': 0.7},
#    'noise': {'noiseLevel': 'medium', 'value': 0.3},
#    'makeup': {'eyeMakeup': False, 'lipMakeup': False},
#    'accessories': [],
#    'occlusion': {'foreheadOccluded': False,
#     'eyeOccluded': False,
#     'mouthOccluded': False},
#    'hair': {'bald': 0.02,
#     'invisible': False,
#     'hairColor': [{'color': 'brown', 'confidence': 1.0},
#      {'color': 'black', 'confidence': 0.6},
#      {'color': 'red', 'confidence': 0.57},
#      {'color': 'blond', 'confidence': 0.13},
#      {'color': 'gray', 'confidence': 0.04},
#      {'color': 'other', 'confidence': 0.03}]}}},
#  {'faceId': '769d2049-dad1-446f-9a3f-b3c2a60b2e8c',
#   'faceRectangle': {'top': 57, 'left': 282, 'width': 51, 'height': 51},
#   'faceAttributes': {'smile': 0.0,
#    'headPose': {'pitch': 20.1, 'roll': 1.9, 'yaw': -3.2},
#    'gender': 'male',
#    'age': 27.0,
#    'facialHair': {'moustache': 0.1, 'beard': 0.1, 'sideburns': 0.1},
#    'glasses': 'NoGlasses',
#    'emotion': {'anger': 0.0,
#     'contempt': 0.0,
#     'disgust': 0.0,
#     'fear': 0.0,
#     'happiness': 0.0,
#     'neutral': 0.995,
#     'sadness': 0.002,
#     'surprise': 0.003},
#    'blur': {'blurLevel': 'high', 'value': 1.0},
#    'exposure': {'exposureLevel': 'goodExposure', 'value': 0.65},
#    'noise': {'noiseLevel': 'low', 'value': 0.18},
#    'makeup': {'eyeMakeup': False, 'lipMakeup': False},
#    'accessories': [],
#    'occlusion': {'foreheadOccluded': False,
#     'eyeOccluded': False,
#     'mouthOccluded': False},
#    'hair': {'bald': 0.06,
#     'invisible': False,
#     'hairColor': [{'color': 'brown', 'confidence': 1.0},
#      {'color': 'black', 'confidence': 0.96},
#      {'color': 'red', 'confidence': 0.2},
#      {'color': 'blond', 'confidence': 0.14},
#      {'color': 'other', 'confidence': 0.04},
#      {'color': 'gray', 'confidence': 0.03}]}}},
#  {'faceId': 'ccc9722e-aded-419f-8bac-b0268a25d0f4',
#   'faceRectangle': {'top': 104, 'left': 127, 'width': 48, 'height': 48},
#   'faceAttributes': {'smile': 0.922,
#    'headPose': {'pitch': 5.9, 'roll': 9.2, 'yaw': 4.0},
#    'gender': 'male',
#    'age': 31.0,
#    'facialHair': {'moustache': 0.1, 'beard': 0.1, 'sideburns': 0.1},
#    'glasses': 'NoGlasses',
#    'emotion': {'anger': 0.0,
#     'contempt': 0.0,
#     'disgust': 0.0,
#     'fear': 0.0,
#     'happiness': 0.922,
#     'neutral': 0.077,
#     'sadness': 0.0,
#     'surprise': 0.0},
#    'blur': {'blurLevel': 'high', 'value': 0.93},
#    'exposure': {'exposureLevel': 'goodExposure', 'value': 0.74},
#    'noise': {'noiseLevel': 'low', 'value': 0.22},
#    'makeup': {'eyeMakeup': False, 'lipMakeup': False},
#    'accessories': [],
#    'occlusion': {'foreheadOccluded': False,
#     'eyeOccluded': False,
#     'mouthOccluded': False},
#    'hair': {'bald': 0.07,
#     'invisible': False,
#     'hairColor': [{'color': 'brown', 'confidence': 0.99},
#      {'color': 'black', 'confidence': 0.94},
#      {'color': 'gray', 'confidence': 0.26},
#      {'color': 'blond', 'confidence': 0.15},
#      {'color': 'red', 'confidence': 0.1},
#      {'color': 'other', 'confidence': 0.08}]}}},
#  {'faceId': '5cc18a76-f0d3-48a9-9e5c-73b40b3835e3',
#   'faceRectangle': {'top': 71, 'left': 387, 'width': 41, 'height': 41},
#   'faceAttributes': {'smile': 0.0,
#    'headPose': {'pitch': 24.7, 'roll': -14.0, 'yaw': -27.8},
#    'gender': 'male',
#    'age': 23.0,
#    'facialHair': {'moustache': 0.1, 'beard': 0.1, 'sideburns': 0.1},
#    'glasses': 'NoGlasses',
#    'emotion': {'anger': 0.001,
#     'contempt': 0.001,
#     'disgust': 0.0,
#     'fear': 0.0,
#     'happiness': 0.0,
#     'neutral': 0.966,
#     'sadness': 0.032,
#     'surprise': 0.0},
#    'blur': {'blurLevel': 'low', 'value': 0.0},
#    'exposure': {'exposureLevel': 'goodExposure', 'value': 0.65},
#    'noise': {'noiseLevel': 'high', 'value': 1.0},
#    'makeup': {'eyeMakeup': False, 'lipMakeup': False},
#    'accessories': [],
#    'occlusion': {'foreheadOccluded': False,
#     'eyeOccluded': False,
#     'mouthOccluded': False},
#    'hair': {'bald': 0.06,
#     'invisible': False,
#     'hairColor': [{'color': 'brown', 'confidence': 0.97},
#      {'color': 'black', 'confidence': 0.8},
#      {'color': 'blond', 'confidence': 0.4},
#      {'color': 'gray', 'confidence': 0.26},
#      {'color': 'red', 'confidence': 0.17},
#      {'color': 'other', 'confidence': 0.15}]}}}]

# %%
import pandas as pd
df2 = pd.json_normalize(results2)
df2 = df2.rename (columns = {"faceAttributes.smile":"笑容","faceAttributes.headPose.roll":"头部偏向（上下）",
                           "faceAttributes.facialHair.beard":"胡须",
                           "faceAttributes.facialHair.sideburns":"胡须角",
                           "faceAttributes.glasses":"佩戴眼镜",
                           "faceAttributes.emotion.anger":"愤怒",
                           "faceAttributes.emotion.contempt":"鄙视",
                           "faceAttributes.headPose.yaw":"头部偏向（左右）",
                           "faceAttributes.gender":"性别","faceAttributes.age":"年龄",
                           "faceAttributes.facialHair.moustache":"有无胡子",
                           "faceAttributes.noise.value":"噪音值",
                           "faceAttributes.makeup.eyeMakeup":"眼妆",
                           "faceAttributes.makeup.lipMakeup":"唇彩",
                           "faceAttributes.accessories":"配饰",
                           "faceAttributes.occlusion.foreheadOccluded":"前额闭塞",
                           "faceAttributes.occlusion.eyeOccluded":"眼睛开合",
                           "faceAttributes.occlusion.mouthOccluded":"嘴巴开合",
                           "faceAttributes.hair.bald":"秃头程度",
                           "faceAttributes.hair.invisible":"看不见头发",
                           "faceAttributes.hair.hairColor":"发色"})
df2 = df2.set_index('faceId')
df2 = df2.iloc[:,6:]
df2.replace({"male":"男",
            "female":"女",
            "NoGlasses":"不佩戴眼镜",
            "Glasses":"佩戴眼镜",})
# Out:
#                                       头部偏向（上下）  头部偏向（左右） 性别    年龄  有无胡子   胡须  \
# faceId
# 37d58420-1611-48c5-98d3-16fc0f4aba2b     -16.8     -12.7  男  26.0   0.1  0.1
# c6fcd741-78b5-424c-a42e-6140ddd408ed     -17.6     -19.2  男  31.0   0.1  0.1
# 1958e854-0811-4a50-a093-c41f762e7110       4.2       5.4  男  24.0   0.1  0.1
# f676b46b-386d-419d-9899-6be914010081       4.4      15.4  男  31.0   0.1  0.1
# 769d2049-dad1-446f-9a3f-b3c2a60b2e8c       1.9      -3.2  男  27.0   0.1  0.1
# ccc9722e-aded-419f-8bac-b0268a25d0f4       9.2       4.0  男  31.0   0.1  0.1
# 5cc18a76-f0d3-48a9-9e5c-73b40b3835e3     -14.0     -27.8  男  23.0   0.1  0.1
#
#                                       胡须角   佩戴眼镜     愤怒     鄙视  ...   噪音值  \
# faceId                                                          ...
# 37d58420-1611-48c5-98d3-16fc0f4aba2b  0.1  不佩戴眼镜  0.000  0.000  ...  0.71
# c6fcd741-78b5-424c-a42e-6140ddd408ed  0.1  不佩戴眼镜  0.000  0.000  ...  0.39
# 1958e854-0811-4a50-a093-c41f762e7110  0.1  不佩戴眼镜  0.000  0.001  ...  0.18
# f676b46b-386d-419d-9899-6be914010081  0.1  不佩戴眼镜  0.000  0.000  ...  0.30
# 769d2049-dad1-446f-9a3f-b3c2a60b2e8c  0.1  不佩戴眼镜  0.000  0.000  ...  0.18
# ccc9722e-aded-419f-8bac-b0268a25d0f4  0.1  不佩戴眼镜  0.000  0.000  ...  0.22
# 5cc18a76-f0d3-48a9-9e5c-73b40b3835e3  0.1  不佩戴眼镜  0.001  0.001  ...  1.00
#
#                                          眼妆     唇彩  配饰   前额闭塞   眼睛开合   嘴巴开合  \
# faceId
# 37d58420-1611-48c5-98d3-16fc0f4aba2b  False  False  []  False  False  False
# c6fcd741-78b5-424c-a42e-6140ddd408ed  False  False  []  False  False  False
# 1958e854-0811-4a50-a093-c41f762e7110   True   True  []  False  False  False
# f676b46b-386d-419d-9899-6be914010081  False  False  []  False  False  False
# 769d2049-dad1-446f-9a3f-b3c2a60b2e8c  False  False  []  False  False  False
# ccc9722e-aded-419f-8bac-b0268a25d0f4  False  False  []  False  False  False
# 5cc18a76-f0d3-48a9-9e5c-73b40b3835e3  False  False  []  False  False  False
#
#                                       秃头程度  看不见头发  \
# faceId
# 37d58420-1611-48c5-98d3-16fc0f4aba2b  0.17  False
# c6fcd741-78b5-424c-a42e-6140ddd408ed  0.19  False
# 1958e854-0811-4a50-a093-c41f762e7110  0.02  False
# f676b46b-386d-419d-9899-6be914010081  0.02  False
# 769d2049-dad1-446f-9a3f-b3c2a60b2e8c  0.06  False
# ccc9722e-aded-419f-8bac-b0268a25d0f4  0.07  False
# 5cc18a76-f0d3-48a9-9e5c-73b40b3835e3  0.06  False
#
#                                                                                      发色
# faceId
# 37d58420-1611-48c5-98d3-16fc0f4aba2b  [{'color': 'brown', 'confidence': 0.98}, {'col...
# c6fcd741-78b5-424c-a42e-6140ddd408ed  [{'color': 'black', 'confidence': 0.97}, {'col...
# 1958e854-0811-4a50-a093-c41f762e7110  [{'color': 'brown', 'confidence': 1.0}, {'colo...
# f676b46b-386d-419d-9899-6be914010081  [{'color': 'brown', 'confidence': 1.0}, {'colo...
# 769d2049-dad1-446f-9a3f-b3c2a60b2e8c  [{'color': 'brown', 'confidence': 1.0}, {'colo...
# ccc9722e-aded-419f-8bac-b0268a25d0f4  [{'color': 'brown', 'confidence': 0.99}, {'col...
# 5cc18a76-f0d3-48a9-9e5c-73b40b3835e3  [{'color': 'brown', 'confidence': 0.97}, {'col...
#
# [7 rows x 31 columns]

# %% [markdown]
# # 运用腾讯云分析人脸数据制作数据表格

# %% [markdown]
# - 单人人脸识别

# %%
results5 = res
results5
# Out:
# {'ret': 0,
#  'msg': 'ok',
#  'data': {'image_width': 1024,
#   'image_height': 1302,
#   'face_list': [{'face_id': '3591677007410278502',
#     'x': 391,
#     'y': 159,
#     'width': 241,
#     'height': 241,
#     'gender': 99,
#     'age': 22,
#     'expression': 11,
#     'beauty': 84,
#     'glass': 0,
#     'pitch': 8,
#     'yaw': 2,
#     'roll': -5,
#     'face_shape': {'face_profile': [{'x': 407, 'y': 224},
#       {'x': 405, 'y': 246},
#       {'x': 406, 'y': 269},
#       {'x': 409, 'y': 291},
#       {'x': 413, 'y': 313},
#       {'x': 420, 'y': 334},
#       {'x': 431, 'y': 353},
#       {'x': 445, 'y': 371},
#       {'x': 461, 'y': 386},
#       {'x': 479, 'y': 398},
#       {'x': 501, 'y': 404},
#       {'x': 522, 'y': 401},
#       {'x': 540, 'y': 390},
#       {'x': 557, 'y': 376},
#       {'x': 571, 'y': 360},
#       {'x': 583, 'y': 343},
#       {'x': 592, 'y': 323},
#       {'x': 599, 'y': 303},
#       {'x': 605, 'y': 283},
#       {'x': 608, 'y': 261},
#       {'x': 609, 'y': 242}],
#      'left_eye': [{'x': 443, 'y': 227},
#       {'x': 450, 'y': 235},
#       {'x': 461, 'y': 239},
#       {'x': 472, 'y': 239},
#       {'x': 483, 'y': 235},
#       {'x': 477, 'y': 225},
#       {'x': 466, 'y': 220},
#       {'x': 453, 'y': 220}],
#      'right_eye': [{'x': 574, 'y': 239},
#       {'x': 565, 'y': 244},
#       {'x': 554, 'y': 246},
#       {'x': 544, 'y': 243},
#       {'x': 534, 'y': 237},
#       {'x': 543, 'y': 230},
#       {'x': 554, 'y': 228},
#       {'x': 565, 'y': 231}],
#      'left_eyebrow': [{'x': 426, 'y': 207},
#       {'x': 441, 'y': 206},
#       {'x': 457, 'y': 206},
#       {'x': 473, 'y': 208},
#       {'x': 488, 'y': 208},
#       {'x': 474, 'y': 197},
#       {'x': 457, 'y': 194},
#       {'x': 439, 'y': 195}],
#      'right_eyebrow': [{'x': 596, 'y': 221},
#       {'x': 578, 'y': 220},
#       {'x': 560, 'y': 219},
#       {'x': 542, 'y': 219},
#       {'x': 524, 'y': 218},
#       {'x': 541, 'y': 208},
#       {'x': 561, 'y': 206},
#       {'x': 581, 'y': 208}],
#      'mouth': [{'x': 464, 'y': 331},
#       {'x': 476, 'y': 338},
#       {'x': 489, 'y': 343},
#       {'x': 503, 'y': 344},
#       {'x': 516, 'y': 344},
#       {'x': 529, 'y': 340},
#       {'x': 541, 'y': 334},
#       {'x': 527, 'y': 334},
#       {'x': 512, 'y': 333},
#       {'x': 503, 'y': 335},
#       {'x': 495, 'y': 333},
#       {'x': 479, 'y': 332},
#       {'x': 477, 'y': 334},
#       {'x': 490, 'y': 337},
#       {'x': 503, 'y': 339},
#       {'x': 516, 'y': 338},
#       {'x': 529, 'y': 336},
#       {'x': 529, 'y': 336},
#       {'x': 516, 'y': 337},
#       {'x': 503, 'y': 339},
#       {'x': 490, 'y': 336},
#       {'x': 477, 'y': 334}],
#      'nose': [{'x': 506, 'y': 288},
#       {'x': 509, 'y': 235},
#       {'x': 500, 'y': 250},
#       {'x': 492, 'y': 264},
#       {'x': 484, 'y': 278},
#       {'x': 475, 'y': 294},
#       {'x': 490, 'y': 303},
#       {'x': 504, 'y': 307},
#       {'x': 517, 'y': 306},
#       {'x': 532, 'y': 299},
#       {'x': 526, 'y': 282},
#       {'x': 520, 'y': 266},
#       {'x': 514, 'y': 251}]}}]}}

# %%
import pandas as pd
df5 = pd.json_normalize(results5)
df5 = df5.rename (columns = {"data.face_list":"列表"})
df5.replace({})
# Out:
#    ret msg  data.image_width  data.image_height  \
# 0    0  ok               440                330
#
#                                                   列表
# 0  [{'face_id': '3591505338030914982', 'x': 178, ...

# %% [markdown]
# - 多人人脸识别

# %%
results6 = res2
results6
# Out:
# {'ret': 0,
#  'msg': 'ok',
#  'data': {'image_width': 640,
#   'image_height': 431,
#   'face_list': [{'face_id': '3591710753910987410',
#     'x': 325,
#     'y': 150,
#     'width': 51,
#     'height': 51,
#     'gender': 99,
#     'age': 23,
#     'expression': 14,
#     'beauty': 78,
#     'glass': 0,
#     'pitch': 7,
#     'yaw': 3,
#     'roll': 0,
#     'face_shape': {'face_profile': [{'x': 329, 'y': 164},
#       {'x': 329, 'y': 168},
#       {'x': 330, 'y': 173},
#       {'x': 331, 'y': 178},
#       {'x': 332, 'y': 182},
#       {'x': 334, 'y': 186},
#       {'x': 336, 'y': 190},
#       {'x': 339, 'y': 194},
#       {'x': 343, 'y': 197},
#       {'x': 347, 'y': 199},
#       {'x': 352, 'y': 200},
#       {'x': 356, 'y': 199},
#       {'x': 360, 'y': 196},
#       {'x': 363, 'y': 193},
#       {'x': 366, 'y': 190},
#       {'x': 368, 'y': 186},
#       {'x': 370, 'y': 181},
#       {'x': 371, 'y': 177},
#       {'x': 372, 'y': 172},
#       {'x': 372, 'y': 168},
#       {'x': 372, 'y': 164}],
#      'left_eye': [{'x': 338, 'y': 164},
#       {'x': 339, 'y': 165},
#       {'x': 341, 'y': 165},
#       {'x': 344, 'y': 165},
#       {'x': 346, 'y': 165},
#       {'x': 344, 'y': 163},
#       {'x': 342, 'y': 162},
#       {'x': 340, 'y': 162}],
#      'right_eye': [{'x': 365, 'y': 164},
#       {'x': 363, 'y': 165},
#       {'x': 361, 'y': 165},
#       {'x': 359, 'y': 165},
#       {'x': 357, 'y': 165},
#       {'x': 359, 'y': 163},
#       {'x': 361, 'y': 162},
#       {'x': 363, 'y': 162}],
#      'left_eyebrow': [{'x': 334, 'y': 159},
#       {'x': 337, 'y': 159},
#       {'x': 341, 'y': 158},
#       {'x': 344, 'y': 158},
#       {'x': 347, 'y': 158},
#       {'x': 344, 'y': 156},
#       {'x': 341, 'y': 156},
#       {'x': 337, 'y': 157}],
#      'right_eyebrow': [{'x': 369, 'y': 159},
#       {'x': 366, 'y': 159},
#       {'x': 362, 'y': 159},
#       {'x': 359, 'y': 159},
#       {'x': 356, 'y': 159},
#       {'x': 359, 'y': 157},
#       {'x': 363, 'y': 156},
#       {'x': 366, 'y': 157}],
#      'mouth': [{'x': 343, 'y': 184},
#       {'x': 345, 'y': 186},
#       {'x': 348, 'y': 187},
#       {'x': 352, 'y': 187},
#       {'x': 355, 'y': 187},
#       {'x': 358, 'y': 186},
#       {'x': 360, 'y': 184},
#       {'x': 357, 'y': 184},
#       {'x': 354, 'y': 183},
#       {'x': 352, 'y': 183},
#       {'x': 349, 'y': 183},
#       {'x': 346, 'y': 184},
#       {'x': 346, 'y': 185},
#       {'x': 349, 'y': 185},
#       {'x': 352, 'y': 185},
#       {'x': 355, 'y': 185},
#       {'x': 357, 'y': 185},
#       {'x': 357, 'y': 184},
#       {'x': 355, 'y': 185},
#       {'x': 352, 'y': 185},
#       {'x': 349, 'y': 185},
#       {'x': 346, 'y': 185}],
#      'nose': [{'x': 352, 'y': 175},
#       {'x': 351, 'y': 164},
#       {'x': 350, 'y': 167},
#       {'x': 348, 'y': 170},
#       {'x': 347, 'y': 173},
#       {'x': 345, 'y': 177},
#       {'x': 349, 'y': 178},
#       {'x': 352, 'y': 179},
#       {'x': 355, 'y': 178},
#       {'x': 358, 'y': 176},
#       {'x': 356, 'y': 173},
#       {'x': 355, 'y': 170},
#       {'x': 353, 'y': 167}]}},
#    {'face_id': '3591710758945200786',
#     'x': 194,
#     'y': 179,
#     'width': 51,
#     'height': 51,
#     'gender': 0,
#     'age': 20,
#     'expression': 20,
#     'beauty': 85,
#     'glass': 0,
#     'pitch': 9,
#     'yaw': 18,
#     'roll': 1,
#     'face_shape': {'face_profile': [{'x': 199, 'y': 195},
#       {'x': 199, 'y': 199},
#       {'x': 200, 'y': 204},
#       {'x': 201, 'y': 208},
#       {'x': 203, 'y': 212},
#       {'x': 206, 'y': 215},
#       {'x': 209, 'y': 217},
#       {'x': 213, 'y': 219},
#       {'x': 217, 'y': 221},
#       {'x': 221, 'y': 221},
#       {'x': 226, 'y': 220},
#       {'x': 228, 'y': 219},
#       {'x': 230, 'y': 216},
#       {'x': 232, 'y': 214},
#       {'x': 233, 'y': 211},
#       {'x': 235, 'y': 209},
#       {'x': 236, 'y': 206},
#       {'x': 237, 'y': 203},
#       {'x': 238, 'y': 200},
#       {'x': 238, 'y': 196},
#       {'x': 238, 'y': 194}],
#      'left_eye': [{'x': 211, 'y': 194},
#       {'x': 212, 'y': 195},
#       {'x': 214, 'y': 196},
#       {'x': 216, 'y': 196},
#       {'x': 218, 'y': 195},
#       {'x': 217, 'y': 193},
#       {'x': 215, 'y': 192},
#       {'x': 213, 'y': 192}],
#      'right_eye': [{'x': 229, 'y': 195},
#       {'x': 231, 'y': 196},
#       {'x': 232, 'y': 196},
#       {'x': 233, 'y': 195},
#       {'x': 235, 'y': 194},
#       {'x': 233, 'y': 193},
#       {'x': 231, 'y': 192},
#       {'x': 230, 'y': 193}],
#      'left_eyebrow': [{'x': 207, 'y': 189},
#       {'x': 211, 'y': 189},
#       {'x': 214, 'y': 189},
#       {'x': 218, 'y': 190},
#       {'x': 222, 'y': 190},
#       {'x': 219, 'y': 188},
#       {'x': 215, 'y': 187},
#       {'x': 210, 'y': 187}],
#      'right_eyebrow': [{'x': 237, 'y': 190},
#       {'x': 234, 'y': 190},
#       {'x': 232, 'y': 190},
#       {'x': 230, 'y': 190},
#       {'x': 228, 'y': 190},
#       {'x': 230, 'y': 189},
#       {'x': 232, 'y': 188},
#       {'x': 235, 'y': 188}],
#      'mouth': [{'x': 218, 'y': 220},
#       {'x': 221, 'y': 220},
#       {'x': 223, 'y': 221},
#       {'x': 226, 'y': 220},
#       {'x': 227, 'y': 218},
#       {'x': 228, 'y': 217},
#       {'x': 228, 'y': 215},
#       {'x': 228, 'y': 214},
#       {'x': 227, 'y': 214},
#       {'x': 226, 'y': 215},
#       {'x': 224, 'y': 215},
#       {'x': 221, 'y': 217},
#       {'x': 221, 'y': 219},
#       {'x': 223, 'y': 218},
#       {'x': 226, 'y': 217},
#       {'x': 227, 'y': 216},
#       {'x': 228, 'y': 215},
#       {'x': 228, 'y': 215},
#       {'x': 227, 'y': 216},
#       {'x': 226, 'y': 216},
#       {'x': 223, 'y': 217},
#       {'x': 221, 'y': 218}],
#      'nose': [{'x': 226, 'y': 207},
#       {'x': 224, 'y': 195},
#       {'x': 223, 'y': 198},
#       {'x': 222, 'y': 202},
#       {'x': 221, 'y': 205},
#       {'x': 219, 'y': 208},
#       {'x': 223, 'y': 210},
#       {'x': 226, 'y': 210},
#       {'x': 228, 'y': 209},
#       {'x': 230, 'y': 208},
#       {'x': 229, 'y': 204},
#       {'x': 227, 'y': 201},
#       {'x': 226, 'y': 198}]}}]}}

# %%
import pandas as pd
df6 = pd.json_normalize(results6)
df6 = df6.rename (columns = {"data.face_list":"列表"})
df6
# Out:
#    ret msg  data.image_width  data.image_height  \
# 0    0  ok               640                431
#
#                                                   列表
# 0  [{'face_id': '3591710753910987410', 'x': 325, ...

# %% [markdown]
# # 运用Face++分析人脸数据制作数据表格

# %% [markdown]
# - 单人人脸识别分析

# %%
results3 = r.json()
results3
# Out:
# {'request_id': '1586688761,2787e3ec-6967-41ca-af3b-7cf2345763e6',
#  'time_used': 1378,
#  'faces': [{'face_token': '7b80b263bb5bc1c47c42637d60748ff3',
#    'face_rectangle': {'top': 199, 'left': 403, 'width': 204, 'height': 204},
#    'attributes': {'gender': {'value': 'Male'},
#     'age': {'value': 22},
#     'smile': {'value': 0.313, 'threshold': 50.0},
#     'emotion': {'anger': 0.0,
#      'disgust': 0.0,
#      'fear': 0.0,
#      'happiness': 0.064,
#      'neutral': 99.932,
#      'sadness': 0.0,
#      'surprise': 0.004}}}],
#  'image_id': 'dRwDYxEHDz3BXhnlNlkSeQ==',
#  'face_num': 1}

# %%
import pandas as pd
df3 = pd.json_normalize(results3,record_path='faces')
df3 = df3.rename (columns = {"attributes.gender.value":"性别",
                           "attributes.age.value":"年龄",
                           "attributes.smile.value":"笑容",
                           "attributes.smile.threshold":"是否有笑容",
                           "attributes.emotion.anger":"愤怒",
                           "attributes.emotion.disgust":"厌恶",
                           "attributes.emotion.fear":"恐惧",
                           "attributes.emotion.happiness":"高兴",
                           "attributes.emotion.neutral":"平静",
                           "attributes.emotion.sadness":"悲伤",
                           "attributes.emotion.surprise":"惊讶"})
df3 = df3.set_index('face_token')
df3 = df3.iloc[:,4:]
df3.replace({"Male":"男",
            "Female":"女",})
# Out:
#                                  性别  年龄     笑容  是否有笑容   愤怒   厌恶   恐惧     高兴  \
# face_token
# 7b80b263bb5bc1c47c42637d60748ff3  男  22  0.313   50.0  0.0  0.0  0.0  0.064
#
#                                       平静   悲伤     惊讶
# face_token
# 7b80b263bb5bc1c47c42637d60748ff3  99.932  0.0  0.004

# %% [markdown]
# - 多人人脸识别

# %%
results4 = r2.json()
results4
# Out:
# {'request_id': '1586690525,97e02306-916e-4c21-a225-0681b35ccfeb',
#  'time_used': 626,
#  'faces': [{'face_token': '982205dcd1b1f8b565531e8810f671c3',
#    'face_rectangle': {'top': 174, 'left': 298, 'width': 117, 'height': 117},
#    'attributes': {'gender': {'value': 'Male'},
#     'age': {'value': 33},
#     'smile': {'value': 99.994, 'threshold': 50.0},
#     'emotion': {'anger': 0.0,
#      'disgust': 0.0,
#      'fear': 0.0,
#      'happiness': 99.795,
#      'neutral': 0.044,
#      'sadness': 0.149,
#      'surprise': 0.012}}},
#   {'face_token': '031ca75144ef6d0b552825d99d9e1199',
#    'face_rectangle': {'top': 95, 'left': 458, 'width': 79, 'height': 79},
#    'attributes': {'gender': {'value': 'Male'},
#     'age': {'value': 42},
#     'smile': {'value': 100.0, 'threshold': 50.0},
#     'emotion': {'anger': 0.0,
#      'disgust': 0.0,
#      'fear': 0.001,
#      'happiness': 99.99,
#      'neutral': 0.0,
#      'sadness': 0.008,
#      'surprise': 0.0}}},
#   {'face_token': '0ac6d248ada5c4711dc2560d5a9367d4',
#    'face_rectangle': {'top': 109, 'left': 37, 'width': 56, 'height': 56},
#    'attributes': {'gender': {'value': 'Male'},
#     'age': {'value': 30},
#     'smile': {'value': 99.971, 'threshold': 50.0},
#     'emotion': {'anger': 0.0,
#      'disgust': 0.002,
#      'fear': 0.0,
#      'happiness': 99.694,
#      'neutral': 0.301,
#      'sadness': 0.0,
#      'surprise': 0.003}}},
#   {'face_token': '9a00fdf4b2aa0a6ee182cb8c2e1e90ec',
#    'face_rectangle': {'top': 115, 'left': 189, 'width': 56, 'height': 56},
#    'attributes': {'gender': {'value': 'Male'},
#     'age': {'value': 24},
#     'smile': {'value': 99.834, 'threshold': 50.0},
#     'emotion': {'anger': 0.004,
#      'disgust': 0.004,
#      'fear': 0.034,
#      'happiness': 86.613,
#      'neutral': 13.339,
#      'sadness': 0.004,
#      'surprise': 0.004}}},
#   {'face_token': 'd1ad067e4cf711bcb782abcfcb37d777',
#    'face_rectangle': {'top': 59, 'left': 281, 'width': 54, 'height': 54},
#    'attributes': {'gender': {'value': 'Male'},
#     'age': {'value': 31},
#     'smile': {'value': 0.019, 'threshold': 50.0},
#     'emotion': {'anger': 0.001,
#      'disgust': 0.0,
#      'fear': 0.001,
#      'happiness': 0.0,
#      'neutral': 99.963,
#      'sadness': 0.001,
#      'surprise': 0.034}}},
#   {'face_token': 'b62e6330351a33a7af6eb71de08bfc53',
#    'face_rectangle': {'top': 70, 'left': 390, 'width': 49, 'height': 49}},
#   {'face_token': '2f06c88ac461caf73ddc87296c2a7229',
#    'face_rectangle': {'top': 108, 'left': 124, 'width': 46, 'height': 46}}],
#  'image_id': 'T1cd/DyC1NDcHwPnSxBEzQ==',
#  'face_num': 7}

# %%
import pandas as pd
df4 = pd.json_normalize(results4,record_path='faces')
df4 = df4.rename (columns = {"attributes.gender.value":"性别",
                           "attributes.age.value":"年龄",
                           "attributes.smile.value":"笑容",
                           "attributes.smile.threshold":"是否有笑容",
                           "attributes.emotion.anger":"愤怒",
                           "attributes.emotion.disgust":"厌恶",
                           "attributes.emotion.fear":"恐惧",
                           "attributes.emotion.happiness":"高兴",
                           "attributes.emotion.neutral":"平静",
                           "attributes.emotion.sadness":"悲伤",
                           "attributes.emotion.surprise":"惊讶"})
df4 = df4.set_index('face_token')
df4 = df4.iloc[:,4:]
df4.replace({"Male":"男",
            "Female":"女",})
# Out:
#                                    性别    年龄       笑容  是否有笑容     愤怒     厌恶  \
# face_token
# 982205dcd1b1f8b565531e8810f671c3    男  33.0   99.994   50.0  0.000  0.000
# 031ca75144ef6d0b552825d99d9e1199    男  42.0  100.000   50.0  0.000  0.000
# 0ac6d248ada5c4711dc2560d5a9367d4    男  30.0   99.971   50.0  0.000  0.002
# 9a00fdf4b2aa0a6ee182cb8c2e1e90ec    男  24.0   99.834   50.0  0.004  0.004
# d1ad067e4cf711bcb782abcfcb37d777    男  31.0    0.019   50.0  0.001  0.000
# b62e6330351a33a7af6eb71de08bfc53  NaN   NaN      NaN    NaN    NaN    NaN
# 2f06c88ac461caf73ddc87296c2a7229  NaN   NaN      NaN    NaN    NaN    NaN
#
#                                      恐惧      高兴      平静     悲伤     惊讶
# face_token
# 982205dcd1b1f8b565531e8810f671c3  0.000  99.795   0.044  0.149  0.012
# 031ca75144ef6d0b552825d99d9e1199  0.001  99.990   0.000  0.008  0.000
# 0ac6d248ada5c4711dc2560d5a9367d4  0.000  99.694   0.301  0.000  0.003
# 9a00fdf4b2aa0a6ee182cb8c2e1e90ec  0.034  86.613  13.339  0.004  0.004
# d1ad067e4cf711bcb782abcfcb37d777  0.001   0.000  99.963  0.001  0.034
# b62e6330351a33a7af6eb71de08bfc53    NaN     NaN     NaN    NaN    NaN
# 2f06c88ac461caf73ddc87296c2a7229    NaN     NaN     NaN    NaN    NaN

# %% [markdown]
# ---
# # 3家API不同之处的结论

# %% [markdown]
# * 通过上面三家人脸识别api的数据和分析对比我们可以看到：
#     - Azure：可以分析图像中人物头部的朝向，发量等特殊数据。
#     - 腾讯云：可以定位五官的具体方位。
#     - Face++：可以同时分析多种情感。
